# %%
# %pip install numpy matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in c:\users\0201392421003\appdata\roaming\python\python312\site-packages (2.5.2)
# Requirement already satisfied: matplotlib in c:\users\0201392421003\appdata\roaming\python\python312\site-packages (3.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\0201392421003\appdata\roaming\python\python312\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\0201392421003\appdata\roaming\python\python312\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in c:\users\0201392421003\appdata\roaming\python\python312\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\0201392421003\appdata\roaming\python\python312\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\0201392421003\appdata\roaming\python\python312\site-packages (from matplotlib) (26.3)
# Requirement already satisfied: pillow>=9 in c:\users\0201392421003\appdata\roaming\python\python312\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\0201392421003\appdata\roaming\python\python312\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\0201392421003\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\0201392421003\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# A partir de uma lista
meu_array = np.array([1, 2, 3, 4, 5])
print("Meu Array:", meu_array)

# criando um array de zeros
zeros = np.zeros((2, 3)) # matriz 2x3 de zeros
print("Array de zeros:\n", zeros)

# criando um array com um intervalo
intervalo = np.arange(0, 11, 2) # de 0 à 10, de 2 em 2
print("Array com intervalo:\n", intervalo)
# Out:
# Meu Array: [1 2 3 4 5]
# Array de zeros:
#  [[0. 0. 0.]
#  [0. 0. 0.]]
# Array com intervalo:
#  [ 0  2  4  6  8 10]

# %%
array_a = np.array([1, 2, 3])
array_b = np.array([4, 5, 6])

soma = array_a + array_b
multiplicacao = array_a * array_b

print("Soma: ", soma)
print("Multiplicação: ", multiplicacao)
# Out:
# Soma:  [5 7 9]
# Multiplicação:  [ 4 10 18]

# %%
anos = [2020, 2021, 2022, 2023, 2024]
vendas = [100, 120, 150, 130, 160]

plt.plot(anos, vendas)
plt.title('Vendas ao longo dos anos')
plt.xlabel('Ano')
plt.ylabel('Vendas (em milhões)')
plt.grid(True)
plt.show()

# %%
produtos = ['Produto A', 'Produto B', 'Produto C']
quantidades = [ 50, 80, 65]

plt.bar(produtos, quantidades)
plt.title('Quantidade de produtos em estoque')
plt.xlabel('Produto')
plt.ylabel('Quantidade')
plt.show()

# %%
np.random.seed(42)
x = np.random.rand(50) * 10
y = np.random.randn(50) * 2

plt.scatter(x, y)
plt.title('Relação entre X e Y')
plt.xlabel('Variável X')
plt.ylabel('Variável Y')
plt.show()

# %%
# gerando dados com Numpy
x = np.linspace(0, 2 * np.pi, 100) # criar os eixos do gráfico
y_seno = np.sin(x) # trajetória da linha
y_cosseno = np.cos(x) 

# criando o gráfico com Matplotlib
plt.plot(x, y_seno, label='Seno')
plt.plot(x, y_cosseno, label='Cosseno')
plt.title('Funções Seno e Cosseno')
plt.xlabel('Ângulo [rad]')
plt.ylabel('Valor')
plt.legend()
plt.grid(True)
plt.show()

# %%
# gera 1000 números aleatórios com média (loc) 0 e desvio padrão (scale) 1
dados = np.random.normal(loc=0, scale=1, size=1000)

# Cria o histograma
# 'bins' define o número de barras no gráfico
plt.hist(dados, bins=30, color='skyblue', edgecolor='black')

plt.title('Histograma de uma Distribuição Normal')
plt.xlabel('Valores')
plt.ylabel('Frequência')

# exibe o gráfico
plt.show()

# %%
# Cria um array de 100 pontos de -2*PI a 2*PI
x = np.linspace(-2 * np.pi, 2 * np.pi, 200)

# Cria uma figura e uma grade de subplots 2x2
# 'fig' é a figura inteira, 'axs' é um array 2x2 com os eixos de cada gráficos
fig, axs = plt.subplots(2, 2, figsize=(10, 8))

# Adiciona um título principal para todos os subplots
fig.suptitle('Múltiplos Gráficos (Subplots)', fontsize=16)

# Gráfico 1 (Canto superior esquerdo)
axs[0, 0].plot(x, np.sin(x), color='blue')
axs[0, 0].set_title('Seno')
axs[0, 0].grid(True)

# gráfico 2 (canto superior direito)
axs[0, 1].plot(x, np.cos(x), color='red')
axs[0, 1].set_title('Cosseno')
axs[0, 1].grid(True)

# Gráfico 3 (canto inferior esquerdo)
axs[1, 0].plot(x, np.tan(x), color='green')
axs[1, 0].set_title('Tangente')
axs[1, 0].set_ylim(-5, 5) # Limita o eixo y para melhor visualização
axs[1, 0].grid(True)

# Gráfico 4 (canto inferior direito)
axs[1, 1].plot(x, x**2, color='purple')
axs[1, 1].set_title('Parábola (x^2)')
axs[1, 1].grid(True)

# Ajusta o layout para evitar a sobreposição de títulos
plt.tight_layout(rect=[0, 0, 1, 0.96])

# Exibe a figura com todos os gráficos
plt.show()

# %%
# Dados categóricos
categorias = [ 'Tecnologia', 'Saúde', 'Educação', 'Transporte']
valores = [45, 25, 15, 15] # Os valores devem somar 100 para um percentual completo

# 'explode' destaca uma fatia do gráfico. O valor indica o quão distante do centro.
explode = (0.1, 0, 0, 0) # Destaca apenas a primeira fatia ('Tecnologia')

# Cria o gráfico de pizza
plt.pie(valores, explode=explode, labels=categorias, autopct='%1.1f%%',
        shadow=True, startangle=90)

# 'autopct' formata os núemros para mostrar como porcentagens
# 'shadow' adiciona uma sombra
# 'startangle' define o ângulo inicial

# grarante que o gráfico seja um círculo
plt.axis('equal')

plt.title('Distribuição de Investimentos por Setor')
plt.show()
