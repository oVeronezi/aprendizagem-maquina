# %% [markdown]
# ### Instalando as dependências.

# %%
# %pip install numpy matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting numpy
#   Obtaining dependency information for numpy from https://files.pythonhosted.org/packages/7f/b9/87fea2769fe1c47c1b5b01d8310772c9d1a85d485de7cf386ef7a3332b02/numpy-2.5.2-cp312-cp312-win_amd64.whl.metadata
#   Downloading numpy-2.5.2-cp312-cp312-win_amd64.whl.metadata (6.6 kB)
# Collecting matplotlib
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/88/89/56649bbaa2fd12e20f3be03dbcc135b0c8676d88bac17977599e3eb442a0/matplotlib-3.11.1-cp312-cp312-win_amd64.whl.metadata
#   Downloading matplotlib-3.11.1-cp312-cp312-win_amd64.whl.metadata (80 kB)
#      ---------------------------------------- 0.0/80.3 kB ? eta -:--:--
#      ---------------------------------------- 0.0/80.3 kB ? eta -:--:--
#      ----- ---------------------------------- 10.2/80.3 kB ? eta -:--:--
#      ------------------- ------------------ 41.0/80.3 kB 653.6 kB/s eta 0:00:01
#      -------------------------------------- 80.3/80.3 kB 897.7 kB/s eta 0:00:00
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/19/e8/6026ed58a64563186a9ee3f29f41261fd1828f527dd93d33b60feca63352/contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata
#   Downloading contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Obtaining dependency information for cycler>=0.10 from https://files.pythonhosted.org/packages/e7/05/c19819d5e3d95294a6f5947fb9b9629efb316b96de511b418c53d245aae6/cycler-0.12.1-py3-none-any.whl.metadata
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.28.2 (from matplotlib)
#   Obtaining dependency information for fonttools>=4.28.2 from https://files.pythonhosted.org/packages/87/36/cccb9bc2a6ab63d1b2980374f0dca72ce95ae267c9b4cfe77455bb70d0d4/fonttools-4.63.0-cp312-cp312-win_amd64.whl.metadata
#   Downloading fonttools-4.63.0-cp312-cp312-win_amd64.whl.metadata (121 kB)
#      ---------------------------------------- 0.0/121.0 kB ? eta -:--:--
#      -------------------------------------- 121.0/121.0 kB 7.4 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Obtaining dependency information for kiwisolver>=1.3.1 from https://files.pythonhosted.org/packages/ad/cf/0348374369ca588f8fe9c338fae49fa4e16eeb10ffb3d012f23a54578a9e/kiwisolver-1.5.0-cp312-cp312-win_amd64.whl.metadata
#   Downloading kiwisolver-1.5.0-cp312-cp312-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\0201392421006\appdata\roaming\python\python312\site-packages (from matplotlib) (26.3)
# Collecting pillow>=9 (from matplotlib)
#   Obtaining dependency information for pillow>=9 from https://files.pythonhosted.org/packages/45/89/da2f7971a317f83d807fdd4065c0af40208e59e692cc43d315a71a0e96d1/pillow-12.3.0-cp312-cp312-win_amd64.whl.metadata
#   Downloading pillow-12.3.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Obtaining dependency information for pyparsing>=3 from https://files.pythonhosted.org/packages/10/bd/c038d7cc38edc1aa5bf91ab8068b63d4308c66c4c8bb3cbba7dfbc049f9c/pyparsing-3.3.2-py3-none-any.whl.metadata
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\0201392421006\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\0201392421006\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading numpy-2.5.2-cp312-cp312-win_amd64.whl (12.5 MB)
#    ---------------------------------------- 0.0/12.5 MB ? eta -:--:--
#    --- ------------------------------------ 0.9/12.5 MB 30.1 MB/s eta 0:00:01
#    ---- ----------------------------------- 1.5/12.5 MB 23.1 MB/s eta 0:00:01
#    -------- ------------------------------- 2.7/12.5 MB 21.1 MB/s eta 0:00:01
#    ---------- ----------------------------- 3.2/12.5 MB 20.7 MB/s eta 0:00:01
#    ------------- -------------------------- 4.2/12.5 MB 20.4 MB/s eta 0:00:01
#    --------------- ------------------------ 4.8/12.5 MB 18.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.4/12.5 MB 17.2 MB/s eta 0:00:01
#    ------------------ --------------------- 5.7/12.5 MB 15.9 MB/s eta 0:00:01
#    ------------------- -------------------- 5.9/12.5 MB 15.1 MB/s eta 0:00:01
#    ------------------- -------------------- 6.2/12.5 MB 13.7 MB/s eta 0:00:01
#    -------------------- ------------------- 6.4/12.5 MB 12.8 MB/s eta 0:00:01
#    --------------------- ------------------ 6.6/12.5 MB 12.0 MB/s eta 0:00:01
#    --------------------- ------------------ 6.7/12.5 MB 11.3 MB/s eta 0:00:01
#    ---------------------- -----------------
2 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.2/7.2 MB 4.1 MB/s eta 0:00:01
#    ------------------------ --------------- 4.4/7.2 MB 4.1 MB/s eta 0:00:01
#    ------------------------ --------------- 4.5/7.2 MB 4.0 MB/s eta 0:00:01
#    ------------------------- -------------- 4.6/7.2 MB 4.0 MB/s eta 0:00:01
#    -------------------------- ------------- 4.7/7.2 MB 3.9 MB/s eta 0:00:01
#    --------------------------- ------------ 5.0/7.2 MB 4.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.1/7.2 MB 4.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.3/7.2 MB 4.0 MB/s eta 0:00:01
#    ------------------------------ --------- 5.6/7.2 MB 4.0 MB/s eta 0:00:01
#    -------------------------------- ------- 5.8/7.2 MB 4.0 MB/s eta 0:00:01
#    -------------------------------- ------- 5.9/7.2 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.2/7.2 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.3/7.2 MB 4.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.4/7.2 MB 4.0 MB/s eta 0:00:01
#    ------------------------------------ --- 6.6/7.2 MB 4.0 MB/s eta 0:00:01
#    ------------------------------------- -- 6.8/7.2 MB 4.0 MB/s eta 0:00:01
#    -------------------------------------- - 6.9/7.2 MB 3.9 MB/s eta 0:00:01
#    -------------------------------------- - 7.0/7.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  7.2/7.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 3.8 MB/s eta 0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
#    ---------------------------------------- 0.0/122.8 kB ? eta -:--:--
#    -------------------------- ------------- 81.9/122.8 kB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 122.8/122.8 kB 1.4 MB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.11.1 numpy-2.5.2 pillow-12.3.0 pyparsing-3.3.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# A partir de uma lista
meu_array = np.array([1, 2, 3, 4, 5])
print("Meu array:", meu_array)

# Criando um array de zeros
zeros = np.zeros((2, 3)) # Matriz 2x3 de zeros
print("Array de zeros: \n", zeros)

#Criando um array com um intervalo
intervalo = np.arange(0, 11, 2) # de 0 a 10, de 2 em 2
print("Array com intervalo: \n", intervalo)
# Out:
# Meu array: [1 2 3 4 5]
# Array de zeros:
#  [[0. 0. 0.]
#  [0. 0. 0.]]
# Array com intervalo:
#  [ 0  2  4  6  8 10]

# %%
array_a = np.array([1, 2, 3])
array_b = np.array([4, 5, 6])

soma = array_a + array_b
multiplicacao = array_a * 2
multiplicacao_array = array_a * array_b

print("Soma:", soma)
print("Multiplicação:", multiplicacao)
print("Multiplicação de array:", multiplicacao_array)
# Out:
# Soma: [5 7 9]
# Multiplicação: [2 4 6]
# Multiplicação de array: [ 4 10 18]

# %%
anos = [2020, 2021, 2022, 2023, 2024]
vendas = [100, 120, 150, 130, 160]

plt.plot(anos, vendas)
plt.title("Vendas ao longo dos anos")
plt.xlabel("Ano")
plt.ylabel("Vendas em (milhões)")
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
produtos = ['Produto A', 'Produto B', 'Produto C']
quantidades = [50, 80, 65]

plt.bar(produtos, quantidades)
plt.title('Quantidade de Produtos em Estoque')
plt.xlabel('Produto')
plt.ylabel('Quantidade')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
np.random.seed(42)
x = np.random.rand(50) * 10
y = 2 * x + np.random.randn(50) * 2

plt.scatter(x, y)
plt.title('Relação entre X e Y')
plt.xlabel('Variavel X')
plt.ylabel('Variavel Y')
plt.show()

# %%
# Gerando dados com Numpy
x = np.linspace(0, 2 * np.pi, 100)
y_seno = np.sin(x)
y_cosseno = np.cos(x)

# Criando o gráfico com Matplotlib
plt.plot(x, y_seno, label='Seno')
plt.plot(x, y_cosseno, label='Cosseno')
plt.title('Funções Seno e Cosseno')
plt.xlabel('Angulo [rad]')
plt.ylabel('Valor')
plt.legend()
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
